# %% [markdown]
# # Data Preprocessing — Qué Cocinar IA
#
# Este notebook carga `data/recipes.csv`, limpia los datos y persiste en sqlite

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path(__file__).resolve().parent.parent
sys.path.insert(0, str(PROJECT_ROOT))

from backend.config import CHROMA_DIR, COLLECTION_NAME, PROJECT_ROOT as ROOT, SQLITE_PATH
from backend.recipe_db import iter_recipes_for_indexing, load_csv_to_sqlite
from backend.vector_store import recipe_to_vector_document

CSV_PATH = ROOT / "data" / "recipes.csv"

# %%
load_csv_to_sqlite(CSV_PATH, Path(SQLITE_PATH))
